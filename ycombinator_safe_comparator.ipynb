# %% [markdown]
# <a href="https://colab.research.google.com/github/cristelrusso/law-and-code-lab/blob/main/ycombinator_safe_comparator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install python-docx
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.3/244.3 kB 4.5 MB/s eta 0:00:00
# ...

# %%
from docx import Document
import difflib
from google.colab import files

# Función para leer un archivo .docx como líneas de texto
def leer_docx_como_lineas(nombre_archivo):
    doc = Document(nombre_archivo)
    return [p.text.strip() for p in doc.paragraphs if p.text.strip()]

# %%
# Subí el archivo base original de YCombinator una vez
print("📤 Subí el TEMPLATE SAFE oficial (solo una vez)")
uploaded_template = files.upload()
template_filename = next(iter(uploaded_template))
template_lineas = leer_docx_como_lineas(template_filename)

print(f"✅ Template cargado: {template_filename}")
# Out:
# 📤 Subí el TEMPLATE SAFE oficial (solo una vez)
#      <input type="file" id="files-eeef708f-9023-4c65-a413-3d54d734f501" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-eeef708f-9023-4c65-a413-3d54d734f501">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...

# %%
def comparar_con_template(template_lineas):
    print("📤 Subí un contrato SAFE revisado para comparar con el template")
    uploaded_revisado = files.upload()
    revisado_filename = next(iter(uploaded_revisado))
    revisado_lineas = leer_docx_como_lineas(revisado_filename)

    print(f"\n📊 Comparando: {revisado_filename} con el template base...\n")

    d = difflib.Differ()
    diff = list(d.compare(template_lineas, revisado_lineas))

    for linea in diff:
        if linea.startswith("- "):
            print(f"❌ ELIMINADA o CAMBIADA del template: {linea[2:]}")
        elif linea.startswith("+ "):
            print(f"➕ AGREGADA en el revisado: {linea[2:]}")

# %%
comparar_con_template(template_lineas)
# Out:
# 📤 Subí un contrato SAFE revisado para comparar con el template
#      <input type="file" id="files-839ad846-5abd-487a-996a-9a39076b9985" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-839ad846-5abd-487a-996a-9a39076b9985">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...
